# %% [markdown]
# # Linear Regression with Scikit-learn

# %% [markdown]
# This wholly uninteresting notebook is here simply to demonstrate how to perform a linear regression analysis with [Scikit-learn](http://scikit-learn.org/stable/index.html) and create associated plots. That is its only goal in life. I will use the built-in Linnerud dataset, which consists of exercise variables (the predictors) and physiological variables (to be predicted) for 20 people. I will predict the `Weight` variable from the three predictors. Plots are made using [Bokeh](http://bokeh.pydata.org/en/latest/).

# %% [markdown]
# ## Setup

# %%
import bokeh.io as bkio
import bokeh.layouts as bklay
import bokeh.models as bkmod
import bokeh.plotting as bkplt

import bkcharts
import numpy as np
import pandas as pd
import sklearn.linear_model
import sklearn.datasets

bkio.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f729b493-a20f-43b6-af65-401f68a3ad9b">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Here I read in the data and display the first few rows so we can get a feel for what it looks like. Scikit-learn prefers to have their datasets pre-split into training and target variables, but having them all in the same dataframe will make life easier when we go to create plots. That said, the designated predictor variables are:
# - Chins
# - Situps
# - Jumps
#
# The response variables are:
# - Weight
# - Waist
# - Pulse
#
# I will only predict `Weight` in this example.

# %%
linnerud = sklearn.datasets.load_linnerud()
train = pd.DataFrame(linnerud['data'], columns=linnerud['feature_names'], dtype=np.int)
test = pd.DataFrame(linnerud['target'], columns=linnerud['target_names'], dtype=np.int)
dat = pd.concat([train, test], axis=1)
del linnerud, train, test

dat.head()
# Out:
#    Chins  Situps  Jumps  Weight  Waist  Pulse
# 0      5     162     60     191     36     50
# 1      2     110     60     189     37     52
# 2     12     101    101     193     38     58
# 3     12     105     37     162     35     62
# 4     13     155     58     189     35     46

# %% [markdown]
# ## Preliminary Plots

# %% [markdown]
# The relationship between `Weight` and `Chins` appears to be relatively linear, as does its relationship with `Situps`. Its relationship with `Jumps` is less clear.

# %%
p1 = bkcharts.Scatter(dat, x='Chins', y='Weight', width=300, height=300)
p2 = bkcharts.Scatter(dat, x='Situps', y='Weight', width=300, height=300)
p3 = bkcharts.Scatter(dat, x='Jumps', y='Weight', width=300, height=300)

grid = bklay.row([p1, p2, p3])
bkplt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="587c5ac2-b6d6-4b67-b2fe-33e0f01917e3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("587c5ac2-b6d6-4b67-b2fe-33e0f01917e3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("587c5ac2-b6d6-4b67-b2fe-33e0f01917e3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '587c5ac2-b6d6-4b67-b2fe-33e0f01917e3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"85378379-b935-4a0e-96eb-2d0ea2e22916":{"roots":{"references":[{"attributes":{"plot":{"id":"642811bd-1407-42e8-91f4-96f4578631aa","subtype":"Chart","type":"Plot"}},"id":"85e75ccc-4976-4203-b303-c901f2f2eaeb","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4a527005-f207-4ace-8f60-4db1549d36fd","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"642811bd-1407-42e8-91f4-96f4578631aa","subtype":"Chart","type":"Plot"}},"id":"23eeb813-19e8-4397-94be-5d4fc029e9eb","type":"HelpTool"},{"attributes":{"location":"top_left","plot":{"id":
type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"82f2509b-9567-4259-ba22-a7f053d8c58a","type":"BoxAnnotation"},{"attributes":{"axis_label":"Jumps","formatter":{"id":"bfefbcd6-ac2d-4c2a ...

# %% [markdown]
# I now remove three potential outliers and re-plot the data. From the plots, we can see that there is one particularly light person, one particularly heavy person, and one particularly jumpy person.

# %%
dat2 = dat.loc[(dat['Jumps'] < 240) & (dat['Weight'] > 140) & (dat['Weight'] < 240)]

# %%
p1 = bkcharts.Scatter(dat2, x='Chins', y='Weight', width=300, height=300)
p2 = bkcharts.Scatter(dat2, x='Situps', y='Weight', width=300, height=300)
p3 = bkcharts.Scatter(dat2, x='Jumps', y='Weight', width=300, height=300)

grid = bklay.row([p1, p2, p3])
bkplt.show(grid)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="695e2ffb-d19c-487a-a5c9-0a0248d18559"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("695e2ffb-d19c-487a-a5c9-0a0248d18559");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("695e2ffb-d19c-487a-a5c9-0a0248d18559");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '695e2ffb-d19c-487a-a5c9-0a0248d18559' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0bf709b6-820a-466a-9920-302c129de07b":{"roots":{"references":[{"attributes":{"plot":{"id":"ddedb27a-2f09-46bb-aff2-57385ed9f4ae","subtype":"Chart","type":"Plot"}},"id":"50158991-8056-49f6-a226-a37ccfe01734","type":"ResetTool"},{"attributes":{"axis_label":"Situps","formatter":{"id":"ffefefd5-4ae1-4b4e-8347-6aff1b6085e2","type":"BasicTickFormatter"},"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"},"ticker":{"id":"4999e7bf-9956-4f54-bc6f-5293226dd9c0","type":"BasicTicker"}},"id":"dfebb0b4-4f53-4d19-8294-0def71ef037f","type":"LinearAxis"},{"attributes":{"plot":{"id":"ddedb27a-2f09-46bb-aff2-57385ed9f4ae","subtype":"Chart","type":"Plot"}},"id":"18db4064-fa67-49d7-a240-b26417e8efe8","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f25cd343-0868-47bd-9585-14f69201e970","type":"Circle"},{"attributes":{"data_source":{"id":"f4e7d9a2-825f-409a-a1c3-40fbc2219fc7","type":"ColumnDataSource"},"glyph":{"id":"f25cd343-0868-47bd-9585-14f69201e970","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"54272cb9-23da-450a-a596-b7e5c8ab4195","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"}},"id":"db384c9b-0081-4fe0-a9a9-eec11e17ed84","type":"Legend"},{"attributes":{"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"}},"id":"3d4500f3-2d63-4b24-ac9c-e203cc39d391","type":"HelpTool"},{"attributes":{"axis_label":"Weight","formatter":{"id":"7744de0d-30b2-4bd2-b343-08d88da323b3","type":"BasicTickFormatter"},"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"},"ticker":{"id":"e21e3835-d1f9-472d-a5d0-2e8657fac50d","type":"BasicTicker"}},"id":"9bab9afc-277c-40ca-8878-2ec88b8e8c1f","type":"LinearAxis"},{"attributes":{},"id":"4999e7bf-9956-4f54-bc6f-5293226dd9c0","type":"BasicTicker"},{"attributes":{"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"},"ticker":{"id":"4999e7bf-9956-4f54-bc6f-5293226dd9c0","type":"BasicTicker"}},"id":"299c2f83-a523-4feb-b3ec-f17dcdf3cc31","type":"Grid"},{"attributes":{},"id":"e21e3835-d1f9-472d-a5d0-2e8657fac50d","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"},"ticker":{"id":"e21e3835-d1f9-472d-a5d0-2e8657fac50d","type":"BasicTicker"}},"id":"7594d8a9-d0bd-4868-bcfc-13c00436021d","type":"Grid"},{"attributes":{"plot":{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"}},"id":"6f0b96d3-7662-40eb-a56e-f5f82db2195a","type":"PanTool"},{"attributes":{"children":[{"id":"1cf5f322-3ab5-405e-bdd8-db054fb1ffbc","subtype":"Chart","type":"Plot"},{"id":"3a13cff3-47f3-43bb-84c6-bb2450d418b5","subtype":"Chart","type":"Plot"},{"id":"ddedb27a-2f09-46bb-aff2-57385ed9f4ae","subtype":"Chart","type":"Plot"}]},"id":"8fa5c7e6-9687-4f97-9d6e-c0427dc18fd3","type":"Row"},{"attributes":{},"id":"ceaf68ec-944a-4595-aec4-959b0bcbbe8d","type":"LinearScale"},{"attributes":{"plot":null,"text":null},"id":"7451cb32-4a61-48f1-bd1a-1b2bd24bbeb2","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5b27230a-71fc-4d64-92a7-f06ce41b96f6","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"1cf5f322-3ab5-405e-bdd8-db054fb1ffbc","subtype":"Chart","type":"Plot"}},"id":"bd4fde94-0ab5-4388-8785-5c2240f0dbc9","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"5b27230a-71fc-4d64-92a7-f06ce41b96f6","type":"BoxAnnotation"},"plot":{"id":"3a13cff3-47f3- ...

# %% [markdown]
# Still not wonderful, but whatever. Let's do some regression anyway and see how it goes.

# %% [markdown]
# ## Multiple Regression

# %%
reg = sklearn.linear_model.LinearRegression()
reg.fit(dat2[['Chins', 'Situps', 'Jumps']], dat2['Weight'])

print('Intercept: ' + str(reg.intercept_))
print('Coefficients: ' + str(reg.coef_))
# Out:
# Intercept: 197.884401948
# Coefficients: [-0.80153307 -0.16154532  0.19594315]

# %% [markdown]
# ## LASSO

# %% [markdown]
# I'm not really done with the multiple regression, but I'll try finding an optimal LASSO hyperparameter for this problem as well, because hey, why not?

# %%
lreg = sklearn.linear_model.LassoCV(eps=0.01, n_alphas=1000, alphas=None, cv=17)
lreg.fit(dat2[['Chins', 'Situps', 'Jumps']], dat2['Weight'])

print('Regularization Parameter: ' + str(lreg.alpha_))
print('Intercept: ' + str(lreg.intercept_))
print('Coefficients: ' + str(lreg.coef_))
# Out:
# Regularization Parameter: 94.2420158942
# Intercept: 192.830359015
# Coefficients: [-0.         -0.09804644  0.        ]
